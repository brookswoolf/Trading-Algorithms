# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5cd0475a46b11f7069288909')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-07-08</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>39</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>31.2%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>145.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>31.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
# ...
