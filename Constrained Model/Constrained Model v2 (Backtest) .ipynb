# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5cd03a449dee08635225d6d5')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-04-05</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>1.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>2.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.6%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
# ...
