# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5ca6ae5d1b15534d61fb41ee')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-10-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>8</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>13.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.94</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
# ...
